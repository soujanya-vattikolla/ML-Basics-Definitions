# %% [markdown]
# <a href="https://colab.research.google.com/github/soujanya-vattikolla/ML-Basics-Definitions/blob/main/Udemy_PandasBuilt_in_Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Data Visualization Exercise**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
viz_df = pd.read_csv("df3")

# %%
viz_df.shape
# Out:
# (500, 4)

# %%
viz_df.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion.**

# %%
viz_df.plot.scatter(x='a',y='b',color='red',s=50,figsize=(12,3))

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
viz_df['a'].plot.hist()

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')

# %%
viz_df['a'].plot.hist(alpha=0.5,bins=25)

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
viz_df[['a','b']].plot.box()

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
viz_df['d'].plot.kde()

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
viz_df['d'].plot.kde(lw=5,ls="--")

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
viz_df.iloc[0:30].plot.area(alpha=0.4)

# %% [markdown]
# Bonus Challenge!
#
# Note, you may find this really hard, reference the solutions if you can't figure it out! ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - use this one for a hint.**

# %%
viz_df.iloc[0:30].plot.area(alpha=0.4)
plt.legend(bbox_to_anchor=(1.0,0.5),loc="upper left")
plt.show()
